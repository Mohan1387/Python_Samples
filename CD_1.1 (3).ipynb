# %%
# pandas and numpy for data manipulation
import pandas as pd
import numpy as np

# matplotlit and seaborn for visualizations
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 22
import seaborn as sns

# Suppress warnings from pandas
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
cd = pd.read_csv('C:/Users/5030694/Documents/Project/CD/CD_Variable_all_28_06_existing_till_Jan_v2.csv')
cd = cd.iloc[:,1:]
print('Training data shape: ', cd.shape)
cd.head()
# Out:
# Training data shape:  (491740, 37)
#             AGMTNO         PROPNO  PREPAIDPOSTPAIDFLAG    LTV  \
# 0  WB3078CD0009160  3078CD0009160                    0  68.18
# 1  WB3078CD0006318  3078CD0006318                    0  77.77
# 2  WB3078CD0007026  3078CD0007026                    0  74.66
# 3  WB3078CD0040195  3078CD0040195                    0  77.78
# 4  WB3078CD0006403  3078CD0006403                    0  77.77
#
#    ACTUAL_LOAN_AMOUNT  LATESTBALANCE  ELIGIBILITYGRID  IS_MOBILE  \
# 0               32611      190758.16              NaN          0
# 1               17032            NaN              5.0          0
# 2               18664       29890.58              NaN          0
# 3               37332      188925.04             16.0          0
# 4               31108        3270.44             22.0          0
#
#    Mobile_Bill_bin  IS_CIBIL_HIT  ... PANNO DRIVING_LICENSE PASSPORT AADHAR  \
# 0                0             1  ...     Y               N        N      Y
# ...

# %%
cd.columns
# Out:
# Index(['AGMTNO', 'PROPNO', 'PREPAIDPOSTPAIDFLAG', 'LTV', 'ACTUAL_LOAN_AMOUNT',
#        'LATESTBALANCE', 'ELIGIBILITYGRID', 'IS_MOBILE', 'Mobile_Bill_bin',
#        'IS_CIBIL_HIT', 'PRODUCT_CODE', 'CITY', 'SCHEME_TYPE', 'RESIDENT_TYPE',
#        'SURROGATE_CAT', 'AGE', 'GENDER', 'QUALIFICATION', 'TICKET_SIZE',
#        'CROSS_SELL_INSURANCE', 'DEALER_CUST_CITY', 'AGE_BIN',
#        'CIBIL_SCORE_NEW_BIN', 'Actual_TAT_Days', 'Disp_Month_bin',
#        'IS_WEEKEND', 'VOTERID', 'PANNO', 'DRIVING_LICENSE', 'PASSPORT',
#        'AADHAR', 'RATION', 'STATE', 'IS_MANDATE_REGISTERED', 'City_Group',
#        'PROD_GROUP', 'IS_EXIST'],
#       dtype='object')

# %% [raw]
# #cd['City_Group'] = cd['City_Group'].astype(str)

# %%
#cd['PROD_GROUP'] = cd['PROD_GROUP'].astype(str)
#cd['AGE_BIN'] = cd['AGE_BIN'].astype(str)
cd[['City_Group','PROD_GROUP','AGE_BIN','PREPAIDPOSTPAIDFLAG', 'IS_MOBILE', 'Mobile_Bill_bin', 'IS_CIBIL_HIT',
       'SURROGATE_CAT', 'TICKET_SIZE', 'CROSS_SELL_INSURANCE',
       'DEALER_CUST_CITY', 'CIBIL_SCORE_NEW_BIN',
       'Disp_Month_bin', 'IS_WEEKEND', 'IS_EXIST']] = cd[['City_Group','PROD_GROUP','AGE_BIN','PREPAIDPOSTPAIDFLAG', 'IS_MOBILE', 'Mobile_Bill_bin', 'IS_CIBIL_HIT',
       'SURROGATE_CAT', 'TICKET_SIZE', 'CROSS_SELL_INSURANCE',
       'DEALER_CUST_CITY', 'CIBIL_SCORE_NEW_BIN',
       'Disp_Month_bin', 'IS_WEEKEND','IS_EXIST']].astype(str)

# %%
cd.head()
# Out:
#             AGMTNO         PROPNO PREPAIDPOSTPAIDFLAG    LTV  \
# 0  WB3078CD0009160  3078CD0009160                   0  68.18
# 1  WB3078CD0006318  3078CD0006318                   0  77.77
# 2  WB3078CD0007026  3078CD0007026                   0  74.66
# 3  WB3078CD0040195  3078CD0040195                   0  77.78
# 4  WB3078CD0006403  3078CD0006403                   0  77.77
#
#    ACTUAL_LOAN_AMOUNT  LATESTBALANCE  ELIGIBILITYGRID IS_MOBILE  \
# 0               32611      190758.16              NaN         0
# 1               17032            NaN              5.0         0
# 2               18664       29890.58              NaN         0
# 3               37332      188925.04             16.0         0
# 4               31108        3270.44             22.0         0
#
#   Mobile_Bill_bin IS_CIBIL_HIT  ... PANNO DRIVING_LICENSE PASSPORT AADHAR  \
# 0               0            1  ...     Y               N        N      Y
# ...

# %%
categories = cd.select_dtypes('object')
categories.columns
# Out:
# Index(['AGMTNO', 'PROPNO', 'PREPAIDPOSTPAIDFLAG', 'IS_MOBILE',
#        'Mobile_Bill_bin', 'IS_CIBIL_HIT', 'PRODUCT_CODE', 'CITY',
#        'SCHEME_TYPE', 'RESIDENT_TYPE', 'SURROGATE_CAT', 'GENDER',
#        'QUALIFICATION', 'TICKET_SIZE', 'CROSS_SELL_INSURANCE',
#        'DEALER_CUST_CITY', 'AGE_BIN', 'CIBIL_SCORE_NEW_BIN', 'Disp_Month_bin',
#        'IS_WEEKEND', 'VOTERID', 'PANNO', 'DRIVING_LICENSE', 'PASSPORT',
#        'AADHAR', 'RATION', 'STATE', 'City_Group', 'PROD_GROUP', 'IS_EXIST'],
#       dtype='object')

# %%
categories.drop(['AGMTNO','PROPNO', 'PRODUCT_CODE', 'CITY'],axis=1,inplace= True)

# %%
categories['IS_MANDATE_REGISTERED'] = cd['IS_MANDATE_REGISTERED']

# %%
categories.head()
# Out:
#   PREPAIDPOSTPAIDFLAG IS_MOBILE Mobile_Bill_bin IS_CIBIL_HIT SCHEME_TYPE  \
# 0                   0         0               0            1       CDOEM
# 1                   0         0               0            1       CDOEM
# 2                   0         0               0            1       CDOEM
# 3                   0         0               0            1       CDSPL
# 4                   0         0               0            1       CDOEM
#
#   RESIDENT_TYPE SURROGATE_CAT GENDER   QUALIFICATION TICKET_SIZE  ... PANNO  \
# 0         OWNED             0   MALE             SSC          10  ...     Y
# 1         OWNED             0   MALE        GRADUATE           8  ...     N
# 2         OWNED             0   MALE  UNDER GRADUATE           8  ...     N
# 3         OWNED             0   MALE        GRADUATE          10  ...     N
# 4         OWNED             0   MALE        GRADUATE          10  ...     N
#
# ...

# %%
type(categories['IS_MANDATE_REGISTERED'])
# Out:
# pandas.core.series.Series

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491740 entries, 0 to 491739
# Data columns (total 37 columns):
# AGMTNO                   491740 non-null object
# PROPNO                   491740 non-null object
# PREPAIDPOSTPAIDFLAG      491740 non-null object
# LTV                      491740 non-null float64
# ACTUAL_LOAN_AMOUNT       491740 non-null int64
# LATESTBALANCE            86726 non-null float64
# ELIGIBILITYGRID          265342 non-null float64
# IS_MOBILE                491740 non-null object
# Mobile_Bill_bin          491740 non-null object
# IS_CIBIL_HIT             491740 non-null object
# PRODUCT_CODE             491740 non-null object
# CITY                     491740 non-null object
# SCHEME_TYPE              491740 non-null object
# RESIDENT_TYPE            487712 non-null object
# SURROGATE_CAT            491740 non-null object
# AGE                      491740 non-null int64
# GENDER                   491704 non-null object
# ...

# %% [raw]
# # plt.figure(figsize = (15, 10))
#
#
# # sns.kdeplot(cd.loc[cd['IS_MANDATE_REGISTERED'] == 0, 'AGE'], label = 'IS_MANDATE_REGISTERED == 0')#,shade=True)
#
# # sns.kdeplot(cd.loc[cd['IS_MANDATE_REGISTERED'] == 1, 'AGE'], label = 'IS_MANDATE_REGISTERED == 1')#,shade=True)
#
# # # Labeling of plot
# # plt.xlabel('Age'); plt.ylabel('IS_MANDATE_REGISTERED'); plt.title('Distribution of Ages');

# %% [raw]
# #sns.pairplot(cd);
# df = categories[['City_Group','IS_MANDATE_REGISTERED']] \
# .groupby(['City_Group','IS_MANDATE_REGISTERED']) \
# .size()
# df = pd.DataFrame(df).reset_index()
# df.columns = ['City_Group','IS_MANDATE_REGISTERED', 'Counts']
# df = df.pivot('City_Group','IS_MANDATE_REGISTERED', 'Counts').reset_index()
#
# df.plot.bar()
# plt.figure(figsize=(15,3))
# plt.show()

# %%
for i in categories.columns:
    if i != 'IS_MANDATE_REGISTERED':
        df = categories[[i,'IS_MANDATE_REGISTERED']] \
        .groupby([i,'IS_MANDATE_REGISTERED']) \
        .size()
        df = pd.DataFrame(df).reset_index()
        # try catch for sorting the x label values
        try:
            df[i] = df[i].astype('int64')
            df = df.sort_values(by=i)
        except:
            try:
                df[i] = df[i].astype('float64')
                df = df.sort_values(by=i)
            except:
                pass            
        df[i] = df[i].astype('str')
        df.columns = [i,'IS_MANDATE_REGISTERED', 'Counts']
        df = df.pivot(i,'IS_MANDATE_REGISTERED', 'Counts').reset_index()

        ax = df.plot.bar(figsize=(15,12),title=i)
        ax.set_ylabel('Count')
        ax.title.set_size(20)
        ax.legend(['Registered','Not Registered'])
        ax.set_xticklabels(pd.Series(var[i]),rotation=360,fontsize=13)
        print('------------------- '+i+' ------------------')
        plt.savefig('C:/Users/5030694/Documents/Project/CD/EDA/'+i+'.png')
        plt.show()
# Out:
# ------------------- PREPAIDPOSTPAIDFLAG ------------------
# ------------------- IS_MOBILE ------------------
# ------------------- Mobile_Bill_bin ------------------
# ------------------- IS_CIBIL_HIT ------------------
# ------------------- SCHEME_TYPE ------------------
# ------------------- RESIDENT_TYPE ------------------
# ------------------- SURROGATE_CAT ------------------
# ------------------- GENDER ------------------
# ------------------- QUALIFICATION ------------------
# ------------------- TICKET_SIZE ------------------
# ------------------- CROSS_SELL_INSURANCE ------------------
# ------------------- DEALER_CUST_CITY ------------------
# ------------------- AGE_BIN ------------------
# ------------------- CIBIL_SCORE_NEW_BIN ------------------
# ------------------- Disp_Month_bin ------------------
# ------------------- IS_WEEKEND ------------------
# ------------------- VOTERID ------------------
# ------------------- PANNO ------------------
# ...

# %%
numbers = cd.select_dtypes(exclude='object')
numbers = numbers.iloc[:,1:]

# %%
numbers.columns
# Out:
# Index(['ACTUAL_LOAN_AMOUNT', 'LATESTBALANCE', 'ELIGIBILITYGRID', 'AGE',
#        'Actual_TAT_Days', 'IS_MANDATE_REGISTERED'],
#       dtype='object')

# %%
numbers.groupby(['IS_MANDATE_REGISTERED']).agg('median')
# Out:
#                        ACTUAL_LOAN_AMOUNT  LATESTBALANCE  ELIGIBILITYGRID  \
# IS_MANDATE_REGISTERED
# 0                                   13192        3926.79             11.0
# 1                                   13000        2757.00             25.0
#
#                        AGE  Actual_TAT_Days
# IS_MANDATE_REGISTERED
# 0                       32                2
# 1                       31                2

# %%
numbers.groupby(['IS_MANDATE_REGISTERED']).agg('mean')
# Out:
#                        ACTUAL_LOAN_AMOUNT  LATESTBALANCE  ELIGIBILITYGRID  \
# IS_MANDATE_REGISTERED
# 0                            15370.277912   32554.995808        36.115481
# 1                            15034.966773   25195.688832        32.824926
#
#                              AGE  Actual_TAT_Days
# IS_MANDATE_REGISTERED
# 0                      33.575554         3.177700
# 1                      32.883909         3.569251

# %%
for i in categories.columns:
    if i != 'IS_MANDATE_REGISTERED':
        df = categories[[i,'IS_MANDATE_REGISTERED']] \
        .groupby([i,'IS_MANDATE_REGISTERED']) \
        .size()
        df = pd.DataFrame(df).reset_index()
        df.columns = [i,'IS_MANDATE_REGISTERED', 'Counts']
        df = df.pivot(i,'IS_MANDATE_REGISTERED', 'Counts').reset_index()
        #print('------------------- '+i+' ------------------')
        print(df)
# Out:
# IS_MANDATE_REGISTERED PREPAIDPOSTPAIDFLAG       0      1
# 0                                       0  416031  54577
# 1                                       1   13656   1464
# 2                                       2    5563    449
# IS_MANDATE_REGISTERED IS_MOBILE       0      1
# 0                             0  220330  27373
# 1                             1  214920  29117
# IS_MANDATE_REGISTERED Mobile_Bill_bin       0      1
# 0                                   0  428876  55850
# 1                                   1    2246    156
# 2                                  10     215     33
# 3                                  11     860     73
# 4                                   2     499     57
# 5                                   3     573     80
# 6                                   4     542     73
# 7                                   5     289     39
# 8                                   6     229     27
# 9                                   7     178     18
# ...

# %%
var = {'City_Group':['(4% - 2%)1','(1%) 2','(0%) 3'],
       'GENDER':['Female','Male'],
       'AADHAR':['No','Yes'],
       'CIBIL_SCORE_NEW_BIN' :['1(<=300)','2(301- 400)','3(401 - 500)','4(501-600)','5(601 - 700)','6(701 - 800)','7(nan)'],
       'PREPAIDPOSTPAIDFLAG':['No Info','Prepaid','Postpaid'],
       'IS_MOBILE':['No','Yes'],
       
       'Mobile_Bill_bin':['0','1 - 50','51 - 100','101 - 150' , '151 - 200',
                          '201 - 250','251 - 300','301 - 350','351 - 400','401 - 450','451 - 500'],
       'IS_CIBIL_HIT':['No','Yes'],
       'SCHEME_TYPE':['CDNOR','CDOEM','CDSPL'],
       'RESIDENT_TYPE':['OWNED','RENT'],
       'SURROGATE_CAT':['None','CarRC','D/C Card','OwnHouseProof','CIBIL',
                        'Repayment','IncomeProof','SAATHI','CRIF','BusinessProof','Banking'],
       'QUALIFICATION':['12TH','GRADUATE','OTHERS','POST-GRADUATE','PROFESSIONAL','SSC','UNDERGRAD'],
       'TICKET_SIZE':['0 - 10','11 - 20','21 - 30','31 - 40','41 -50',
                      '51 - 60','61 -70','71 -80','81 -90','91 -100'],
       'CROSS_SELL_INSURANCE':['No Insurance','Insured'],
       'DEALER_CUST_CITY':['Same','Not Same'],
       'AGE_BIN':['23 - 24','25 - 26','27 - 28','29 - 30','31 - 33','34 - 36','37 - 40','41 - 46','47 &above'],
       'Disp_Month_bin':['1 - 10','11 - 20','21 - 30'],
       'IS_WEEKEND':['No','Yes'],
       'VOTERID':['No','Yes'],
       'PANNO':['No','Yes'],
       'DRIVING_LICENSE':['No','Yes'],
       'PASSPORT':['No','Yes'],
       'AADHAR':['No','Yes'],
       'RATION':['No','Yes'],
       'STATE':['AP','KA','MH','TN','WB'],
       'PROD_GROUP':['97 %','3 %'],
       'IS_EXIST':['No','Yes']  
      }

# %%
print(var)
# Out:
# {'City_Group': ['(4% - 2%)1', '(1%) 2', '(0%) 3'], 'GENDER': ['Female', 'Male'], 'AADHAR': ['No', 'Yes'], 'CIBIL_SCORE_NEW_BIN': ['1(<=300)', '2(301- 400)', '3(401 - 500)', '4(501-600)', '5(601 - 700)', '6(701 - 800)', '7(nan)'], 'PREPAIDPOSTPAIDFLAG': ['0', '1', '2'], 'IS_MOBILE': ['0', '1'], 'Mobile_Bill_bin': ['0', '1 - 50', '51 - 100', '101 - 150', '151 - 200', '201 - 250', '251 - 300', '301 - 350', '351 - 400', '401 - 450', '451 - 500'], 'IS_CIBIL_HIT': ['No', 'Yes'], 'SCHEME_TYPE': ['CDNOR', 'CDOEM', 'CDSPL'], 'RESIDENT_TYPE': ['OWNED', 'RENT'], 'SURROGATE_CAT': ['None', 'Car RC', 'Debit/Credit Card', 'Own house proof', 'CIBIL', 'Repayment', 'Income Proof', 'SAATHI', 'CRIF', 'Business Proof', 'Banking'], 'QUALIFICATION': ['12TH', 'GRADUATE', 'OTHERS', 'POST-GRADUATE', 'PROFESSIONAL', 'SSC', 'UNDERGRAD'], 'TICKET_SIZE': ['0 - 10', '11 - 20', '21 - 30', '31 - 40', '41 -50', '51 - 60', '61 -70', '71 -80', '81 -90', '91 -100'], 'CROSS_SELL_INSURANCE': ['No Insurance', 'Insured'], '
# ...

# %%
df = categories[['TICKET_SIZE','IS_MANDATE_REGISTERED']] \
.groupby(['TICKET_SIZE','IS_MANDATE_REGISTERED']) \
.size()
df = pd.DataFrame(df).reset_index()
df['TICKET_SIZE'] = df['TICKET_SIZE'].astype('int64')
df = df.sort_values(by='TICKET_SIZE')
df.columns = ['TICKET_SIZE','IS_MANDATE_REGISTERED', 'Counts']
df = df.pivot('TICKET_SIZE','IS_MANDATE_REGISTERED', 'Counts').reset_index()
df#.sort_values(by='TICKET_SIZE')
# Out:
# IS_MANDATE_REGISTERED  TICKET_SIZE      0     1
# 0                                1  49772  6637
# 1                                2  47928  6540
# 2                                3  44306  5525
# 3                                4  45196  5791
# 4                                5  38172  5092
# 5                                6  38681  5482
# 6                                7  39797  5554
# 7                                8  50186  6182
# 8                                9  38081  4766
# 9                               10  43131  4921

# %%
df = categories[['City_Group','IS_MANDATE_REGISTERED']] \
.groupby(['City_Group','IS_MANDATE_REGISTERED']) \
.size()
df = pd.DataFrame(df).reset_index()
df.columns = ['City_Group','IS_MANDATE_REGISTERED', 'Counts']
df = df.pivot('City_Group','IS_MANDATE_REGISTERED', 'Counts').reset_index()
df#.sort_values(by='TICKET_SIZE')
# Out:
# IS_MANDATE_REGISTERED City_Group       0      1
# 0                            1.0  169447  22222
# 1                            2.0  191284  24430
# 2                            3.0   74519   9838

# %%
df.sort_values(by='TICKET_SIZE')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-f9c7f4552cc4> in <module>
# ----> 1 df.sort_values(by='TICKET_SIZE')
#
# TypeError: sort_values() got an unexpected keyword argument 'by'

# %%
df = categories[['Mobile_Bill_bin','IS_MANDATE_REGISTERED']] \
.groupby(['Mobile_Bill_bin','IS_MANDATE_REGISTERED']) \
.size()
df = pd.DataFrame(df).reset_index()
df['Mobile_Bill_bin'] = df['Mobile_Bill_bin'].astype('int64')
df = df.sort_values(by='Mobile_Bill_bin')
df.columns = ['Mobile_Bill_bin','IS_MANDATE_REGISTERED', 'Counts']
df = df.pivot('Mobile_Bill_bin','IS_MANDATE_REGISTERED', 'Counts').reset_index()

ax = df.plot.bar(figsize=(12,7),title='Mobile_Bill_bin')
ax.set_ylabel('Count')
ax.title.set_size(20)
#ax.legend(['Registered','Not Registered'])
ax.set_xticklabels(pd.Series(var['Mobile_Bill_bin']),rotation=360)
plt.show()

# %%
df = categories[['Mobile_Bill_bin','IS_MANDATE_REGISTERED']] \
.groupby(['Mobile_Bill_bin','IS_MANDATE_REGISTERED']) \
.size()
df = pd.DataFrame(df).reset_index()
df['Mobile_Bill_bin'] = df['Mobile_Bill_bin'].astype('int64')
df = df.sort_values(by='Mobile_Bill_bin')
df.columns = ['Mobile_Bill_bin','IS_MANDATE_REGISTERED', 'Counts']
df = df.pivot('Mobile_Bill_bin','IS_MANDATE_REGISTERED', 'Counts').reset_index()
df
# Out:
# IS_MANDATE_REGISTERED  Mobile_Bill_bin       0      1
# 0                                    0  428876  55850
# 1                                    1    2246    156
# 2                                    2     499     57
# 3                                    3     573     80
# 4                                    4     542     73
# 5                                    5     289     39
# 6                                    6     229     27
# 7                                    7     178     18
# 8                                    8     522     66
# 9                                    9     221     18
# 10                                  10     215     33
# 11                                  11     860     73

# %%
df = categories[['GENDER','IS_MANDATE_REGISTERED']] \
.groupby(['GENDER','IS_MANDATE_REGISTERED']) \
.size()
df = pd.DataFrame(df).reset_index()
df['GENDER'] = df['GENDER'].astype('int64')
df = df.sort_values(by='GENDER')
df.columns = ['GENDER','IS_MANDATE_REGISTERED', 'Counts']
df = df.pivot('GENDER','IS_MANDATE_REGISTERED', 'Counts').reset_index()
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-e216f4413756> in <module>
#       3 .size()
#       4 df = pd.DataFrame(df).reset_index()
# ----> 5 df['GENDER'] = df['GENDER'].astype('int64')
#       6 df = df.sort_values(by='GENDER')
#       7 df.columns = ['GENDER','IS_MANDATE_REGISTERED', 'Counts']
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     529
# ...

# %%
for i in categories.columns:
    if i != 'IS_MANDATE_REGISTERED':
        df = categories[[i,'IS_MANDATE_REGISTERED']] \
        .groupby([i,'IS_MANDATE_REGISTERED']) \
        .size()
        df = pd.DataFrame(df).reset_index()
        # try catch for sorting the x label values
        try:
            df[i] = df[i].astype('int64')
            df = df.sort_values(by=i)
        except:
            try:
                df[i] = df[i].astype('float64')
                df = df.sort_values(by=i)
            except:
                pass            
        df[i] = df[i].astype('str')
        df.columns = [i,'IS_MANDATE_REGISTERED', 'Counts']
        df = df.pivot(i,'IS_MANDATE_REGISTERED', 'Counts').reset_index()

        ax = df.plot.bar(figsize=(16,14),title=i)
        ax.set_ylabel('Count')
        ax.title.set_size(20)
        ax.legend(['Registered','Not Registered'])
        ax.set_xticklabels(pd.Series(var[i]),rotation=360,fontsize=13)
        print('------------------- '+i+' ------------------')
        plt.savefig('C:/Users/5030694/Documents/Project/CD/EDA/'+i+'.png')
        plt.show()
# Out:
# ------------------- PREPAIDPOSTPAIDFLAG ------------------
# ------------------- IS_MOBILE ------------------
# ------------------- Mobile_Bill_bin ------------------
# ------------------- IS_CIBIL_HIT ------------------
# ------------------- SCHEME_TYPE ------------------
# ------------------- RESIDENT_TYPE ------------------
# ------------------- SURROGATE_CAT ------------------
# ------------------- GENDER ------------------
# ------------------- QUALIFICATION ------------------
# ------------------- TICKET_SIZE ------------------
# ------------------- CROSS_SELL_INSURANCE ------------------
# ------------------- DEALER_CUST_CITY ------------------
# ------------------- AGE_BIN ------------------
# ------------------- CIBIL_SCORE_NEW_BIN ------------------
# ------------------- Disp_Month_bin ------------------
# ------------------- IS_WEEKEND ------------------
# ------------------- VOTERID ------------------
# ------------------- PANNO ------------------
# ...
